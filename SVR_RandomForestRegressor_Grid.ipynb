# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("/content/insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dep=dataset[["charges"]]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import RandomForestRegressor
param_grid={'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

#fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter{}:",format(grid.best_params_))
# Out:
# The R_score value for best parameter{}: {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.039695      0.004849         0.004553        0.000529
# 1        0.573732      0.063818         0.024636        0.006912
# 2        0.038223      0.010189         0.007559        0.004340
# 3        0.369006      0.088601         0.019556        0.003970
# 4        0.028963      0.001128         0.004698        0.000667
# 5        0.235421      0.003386         0.014191        0.000831
# 6        0.192581      0.005477         0.004268        0.000595
# 7        1.842958      0.011355         0.014108        0.001806
# 8        0.109880      0.001995         0.004046        0.000209
# 9        1.062677      0.017131         0.011198        0.000336
# 10       0.111048      0.006411         0.005829        0.003410
# 11       1.683490      0.434453         0.018621        0.007299
# 12       0.035034      0.000788         0.003650        0.000150
# 13       0.314065      0.016930         0.012510        0.000959
# 14       0.027689      0.002358         0.004039        0.000106
# 15       0.228767      0.001631         0.013132        0.000839
# 16       0.027199      0.001018         0.003902        0.000219
# 17       0.236038      0.005029         0.013431        0.000861
# 18       0.039350      0.000613         0.003876        0.000115
# 19       0.351808      0.010502         0.014057        0.001375
# 20       0.029012      0.000927         0.003863        0.000135
# 21       0.261532      0.004765         0.013137        0.001377
# 22       0.031303      0.001216         0.004257        0.000458
# 23       0.242282      0.034209         0.012875        0.002113
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
# 18         poisson               auto                 10
# 19         poisson               auto                100
# 20         poisson               sqrt                 10
# 21         poisson               sqrt                100
# 22         poisson               log2                 10
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.824811
# 1   {'criterion': 'squared_error', 'max_features':...           0.846739
# 2   {'criterion': 'squared_error', 'max_features':...           0.854934
# 3   {'criterion': 'squared_error', 'max_features':...           0.858896
# 4   {'criterion': 'squared_error', 'max_features':...           0.847816
# 5   {'criterion': 'squared_error', 'max_features':...           0.858696
# 6   {'criterion': 'absolute_error', 'max_features'...           0.819422
# 7   {'criterion': 'absolute_error', 'max_features'...           0.839279
# 8   {'criterion': 'absolute_error', 'max_features'...           0.844199
# 9   {'criterion': 'absolute_error', 'max_features'...           0.857513
# 10  {'criterion': 'absolute_error', 'max_features'...           0.840483
# 11  {'criterion': 'absolute_error', 'max_features'...           0.859240
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.839791
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.850193
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.853325
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.862102
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.843584
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.857034
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.827366
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.843759
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.844303
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859079
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.833832
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.861875
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.770139           0.857709           0.817882
# 1            0.770964           0.857153           0.821800
# 2            0.773064           0.853366           0.815570
# 3            0.781392           0.861511           0.834302
# 4            0.749593           0.853045           0.806185
# 5            0.781529           0.860272           0.826925
# 6            0.759253           0.839584           0.808889
# 7            0.765202           0.851472           0.824331
# 8            0.771863           0.845471           0.806101
# 9            0.781990           0.860219           0.828955
# 10           0.753786           0.848188           0.811754
# 11           0.777780           0.852680           0.827675
# 12           0.767056           0.853569           0.821062
# 13           0.771199           0.859656           0.821657
# 14           0.750110           0.848768           0.817675
# 15           0.783672           0.861308           0.830911
# 16           0.755034           0.845656           0.816667
# 17           0.784047           0.860148           0.830144
# 18           0.749924           0.859819           0.827916
# 19           0.770258           0.856732           0.820312
# 20           0.763265           0.833816           0.812264
# 21           0.783345           0.862841           0.827208
# 22           0.760707           0.851088           0.815358
# 23           0.779983           0.864224           0.827687
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.827609         0.819630        0.028259               15
# 1            0.837457         0.826823        0.030249               10
# 2            0.819472         0.823281        0.030009               13
# 3            0.840051         0.835230        0.028891                2
# 4            0.835123         0.818353        0.038023               17
# 5            0.835035         0.832491        0.028611                7
# 6            0.819044         0.809239        0.026905               24
# 7            0.839394         0.823936        0.030602               12
# 8            0.826122         0.818751        0.027475               16
# 9            0.843573         0.834450        0.028500                4
# 10           0.814268         0.813696        0.033168               23
# 11           0.840675         0.831610        0.028992                8
# 12           0.827605         0.821817        0.029543               14
# 13           0.833852         0.827311        0.030962                9
# 14           0.815396         0.817055        0.036894               21
# 15           0.838436         0.835286        0.028598                1
# 16           0.826015         0.817391        0.033010               18
# 17           0.838869         0.834048        0.027380                5
# 18           0.821469         0.817299        0.036273               20
# 19           0.841327         0.826478        0.030441               11
# 20           0.827761         0.816282        0.028465               22
# 21           0.843136         0.835122        0.028810                3
# 22           0.825720         0.817341        0.030635               19
# 23           0.834484         0.833651        0.030489                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
