# %%
#!pip install scikit-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("/content/insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dep=dataset[["charges"]]

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.metrics.pairwise import linear_kernel

# Define the parameter grid for GridSearchCV
param_grid = {'kernel': ['linear', 'poly', 'rbf', 'sigmoid'], 'C': [1000]}
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)

# create a kernel matrix
#K = linear_kernel(indep_scaled)  # Use the scaled input data

# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1000],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter{}:",format(grid.best_params_))
# Out:
# The R_score value for best parameter{}: {'C': 1000, 'kernel': 'linear'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       1.403837      0.363786         0.025058        0.008031    1000
# 1       0.306003      0.007656         0.031693        0.007888    1000
# 2       0.220274      0.023853         0.055084        0.013284    1000
# 3       0.186239      0.053993         0.035613        0.011342    1000
#
#   param_kernel                            params  split0_test_score  \
# 0       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 1         poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 2          rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 3      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.675162           0.680002           0.699377           0.677952
# 1          -0.028469          -0.073376          -0.086611          -0.134493
# 2          -0.098267          -0.123724          -0.137137          -0.206405
# 3          -2.686121          -2.194563          -2.210858          -1.942521
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.693778        0.022955                1
# 1        -0.080695        0.033795                2
# 2        -0.144193        0.036262                3
# 3        -2.215441        0.255409                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
